# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# Importing the Dataset

# %%
#importing the Data Set
df = pd.read_table('/content/SMSSpamCollection', header=None)
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       5572 non-null   object
#  1   1       5572 non-null   object
# dtypes: object(2)
# memory usage: 87.2+ KB

# %%
#converting label column to numerical
y=df[0]
raw_text=df[1]
le = LabelEncoder()
y_enc = le.fit_transform(y)

# %%
y_enc
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %% [markdown]
# #Text Pre-Processing

# %% [markdown]
# *  Replace URLs with 'httpaddr'
# *   Replace email addresses with 'emailaddr'
# *   Replace money symbols with 'moneysymb'
# *   Replace phone numbers with 'phonenumbr'
# *   Replace numbers with 'numbr'

# %%
print(raw_text)
#1 Replace email addresses with 'emailaddr'
processed = raw_text.str.replace(r'\b[\w\-.]+?@\w+?\.\w{2,4}\b','emailaddr')
print(processed[0])
#2 Replace URLs with 'httpaddr'
processed = processed.str.replace(r'(http[s]?\S+)|(\w+\.[A-Za-z]{2,4}\S*)','httpaddr')
print(processed[0])
#3 Replace money symbols with 'moneysymb'
processed = processed.str.replace(r'£|\$', 'moneysymb')
print(processed[0])
#4 Replace phone numbers with 'phonenumbr'    
processed = processed.str.replace(r'\b(\+\d{1,2}\s)?\d?[\-(.]?\d{3}\)?[\s.-]?\d{3}[\s.-]?\d{4}\b','phonenumbr')
print(processed[0])
#5 Replace numbers with 'numbr'    
processed = processed.str.replace(r'\d+(\.\d+)?', 'numbr')
print(processed[0])
# Out:
# 0       Go until jurong point, crazy.. Available only ...
# 1                           Ok lar... Joking wif u oni...
# 2       Free entry in 2 a wkly comp to win FA Cup fina...
# 3       U dun say so early hor... U c already then say...
# 4       Nah I don't think he goes to usf, he lives aro...
#                               ...
# 5567    This is the 2nd time we have tried 2 contact u...
# 5568                 Will ü b going to esplanade fr home?
# 5569    Pity, * was in mood for that. So...any other s...
# 5570    The guy did some bitching but I acted like i'd...
# 5571                           Rofl. Its true to its name
# Name: 1, Length: 5572, dtype: object
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...

# %% [markdown]
# Removing Punctuations ,white spaces and line breaks

# %%
#1 removing white spaces
processed = processed.str.replace(r'[^\w\d\s]', ' ')
print(processed[0])
#2 removing  line spaces
processed = processed.str.replace(r'\s+', ' ')
print(processed[0])
#3 removing punctuations
processed = processed.str.replace(r'^\s+|\s+?$', '')
print(processed[0])
# Out:
# Go until jurong point  crazy   Available only in bugis n great world la e buffet    Cine there got amore wat
# Go until jurong point crazy Available only in bugis n great world la e buffet Cine there got amore wat
# Go until jurong point crazy Available only in bugis n great world la e buffet Cine there got amore wat

# %% [markdown]
# converting all words to similar cases

# %%
processed = processed.str.lower()
print(processed[0])
# Out:
# go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat

# %% [markdown]
# Removing stop words

# %%
# !pip install -q wordcloud
import wordcloud

import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
#Removing stop words
stop_words = nltk.corpus.stopwords.words('english')
#stop_words

# %%
# converting it to set to iterate faster and removing stop words
processed = processed.apply(lambda x: ' '.join(term for term in x.split() if term not in set(stop_words)))
processed[0]
# Out:
# 'go jurong point crazy available bugis n great world la e buffet cine got amore wat'

# %% [markdown]
# STEMMING

# %%
#stemming........? 
#"distribute", "distributing", "distributor" or "distribution". We can replace these four words with just "distribut"
# available, availabilityetc to avail
porter = nltk.PorterStemmer()
processed = processed.apply(lambda x: ' '.join(porter.stem(term) for term in x.split()))
processed[0]
# Out:
# 'go jurong point crazi avail bugi n great world la e buffet cine got amor wat'

# %% [markdown]
# 3. Feature Engineering

# %%
#Tokenization to create bag of words
vectorizer = TfidfVectorizer(ngram_range=(1,3))
X_ngrams = vectorizer.fit_transform(processed)
vectorizer.vocabulary_
# Out:
# {'go': 20275,
#  'jurong': 28072,
#  'point': 45594,
#  'crazi': 10662,
#  'avail': 3135,
#  'bugi': 6166,
#  'great': 22009,
#  'world': 65859,
#  'la': 29098,
#  'buffet': 6158,
#  'cine': 8518,
#  'got': 21515,
#  'amor': 1624,
#  'wat': 63503,
#  'go jurong': 20512,
#  'jurong point': 28073,
#  'point crazi': 45599,
#  'crazi avail': 10665,
#  'avail bugi': 3138,
#  'bugi great': 6169,
#  'great world': 22146,
#  'world la': 65882,
#  'la buffet': 29099,
#  'buffet cine': 6159,
#  'cine got': 8529,
#  'got amor': 21520,
#  'amor wat': 1625,
#  'go jurong point': 20513,
#  'jurong point crazi': 28074,
#  'point crazi avail': 45600,
#  'crazi avail bugi': 10666,
#  'avail bugi great': 3139,
#  'bugi great world': 6170,
#  'great world la': 22147,
#  'world la buffet': 65883,
#  'la buffet cine': 29100,
#  'buffet cine got': 6160,
#  'cine got amor': 8530,
#  'got amor wat': 21521,
#  'ok': 41896,
#  'lar': 29266,
#  'joke': 27859,
#  'wif': 64825,
#  'oni': 42643,
#  'ok lar': 42016,
#  'lar joke': 29287,
#  'joke wif': 27878,
#  'wif oni': 64856,
#  'ok lar joke': 42019,
#  'lar joke wif': 29288,
#  'joke wif oni': 27879,
#  'free': 17954,
#  'entri': 15183,
#  'numbr': 38758,
#  'wkli': 65350,
#  'comp': 9707,
#  'win': 64947,
#  'fa': 16117,
#  'cup': 10953,
#  'final': 16901,
#  'tkt': 59064,
#  'numbrst': 41196,
#  'may': 33648,
#  'text': 57100,
#  'receiv': 47793,
#  'question': 46952,
#  'std': 54557,
#  'txt': 60683,
#  'rate': 47266,
#  'appli': 2276,
#  'numbrovernumbr': 41022,
#  'free entri': 18019,
#  'entri numbr': 15188,
#  'numbr wkli': 40571,
#  'wkli comp': 65351,
#  'comp win': 9716,
#  'win fa': 64954,
#  'fa cup': 16118,
#  'cup final': 10956,
#  'final tkt': 16940,
#  'tkt numbrst': 59067,
#  'numbrst may': 41210,
#  'may numbr': 33705,
#  'numbr text': 40343,
#  'text fa': 57166,
#  'fa numbr': 16120,
#  'numbr receiv': 40092,
#  'receiv entri': 47798,
#  'entri question': 15196,
#  'question std': 46978,
#  'std txt': 54563,
#  'txt rate': 60782,
#  'rate appli': 47268,
#  'appli numbrovernumbr': 2289,
#  'free entri numbr': 18022,
#  'entri numbr wkli': 15195,
#  'numbr wkli comp': 40572,
#  'wkli comp win': 65354,
#  'comp win fa': 9717,
#  'win fa cup': 64955,
#  'fa cup final': 16119,
#  'cup final tkt': 10958,
#  'final tkt numbrst': 16941,
#  'tkt numbrst may': 59068,
#  'numbrst may numbr': 41211,
#  'may numbr text': 33706,
#  'numbr text fa': 40345,
#  'text fa numbr': 57167,
#  'fa numbr receiv': 16121,
#  'numbr receiv entri': 40093,
#  'receiv entri question': 47799,
#  'entri question std': 15197,
#  'question std txt': 46979,
#  'std txt rate': 54564,
#  'txt rate appli': 60783,
#  'rate appli numbrovernumbr': 47269,
#  'dun': 14141,
#  'say': 49845,
#  'earli': 14308,
#  'hor': 25297,
#  'alreadi': 1172,
#  'dun say': 14186,
#  'say earli': 49894,
#  'earli hor': 14320,
#  'hor alreadi': 25298,
#  'alreadi say': 1249,
#  'dun say earli': 14188,
#  'say earli hor': 49895,
#  'earli hor alreadi': 14321,
#  'hor alreadi say': 25299,
#  'nah': 36863,
#  'think': 57929,
#  'goe': 20922,
#  'usf': 62097,
#  'live': 31108,
#  'around': 2513,
#  'though': 58318,
#  'nah think': 36880,
#  'think goe': 58006,
#  'goe usf': 20945,
#  'usf live': 62108,
#  'live around': 31110,
#  'around though': 2575,
#  'nah think goe': 36881,
#  'think goe usf': 58007,
#  'goe usf live': 20946,
#  'usf live around': 62109,
#  'live around though': 31111,
#  'freemsg': 18236,
#  'hey': 24135,
#  'darl': 11457,
#  'week': 64014,
#  'word': 65622,
#  'back': 3584,
#  'like': 30528,
#  'fun': 18777,
#  'still': 54633,
#  'tb': 56563,
#  'xxx': 66419,
#  'chg': 8292,
#  'send': 50807,
#  'moneysymbnumbr': 35583,
#  'rcv': 47324,
#  'freemsg hey': 18247,
#  'hey darl': 24181,
#  'darl numbr': 11463,
#  'numbr week': 40533,
#  'week word': 64164,
#  'word back': 65626,
#  'back like': 3659,
#  'like fun': 30620,
#  'fun still': 18807,
#  'still tb': 54826,
#  'tb ok': 56567,
#  'ok xxx': 42200,
#  'xxx std': 66432,
#  'std chg': 54558,
#  'chg send': 8294,
#  'send moneysymbnumbr': 50935,
#  'moneysymbnumbr rcv': 35716,
#  'freemsg hey darl': 18249,
#  'hey darl numbr': 24182,
#  'darl numbr week': 11464,
#  'numbr week word': 40539,
#  'week word back': 64165,
#  'word back like': 65627,
#  'back like fun': 3660,
#  'like fun still': 30621,
#  'fun still tb': 18808,
#  'still tb ok': 54827,
#  'tb ok xxx': 56568,
#  'ok xxx std': 42201,
#  'xxx std chg': 66433,
#  'std chg send': 54559,
#  'chg send moneysymbnumbr': 8295,
#  'send moneysymbnumbr rcv': 50936,
#  'even': 15411,
#  'brother': 5955,
#  'speak': 53900,
#  'treat': 60128,
#  'aid': 848,
#  'patent': 43665,
#  'even brother': 15425,
#  'brother like': 5967,
#  'like speak': 30812,
#  'speak treat': 53927,
#  'treat like': 60135,
#  'like aid': 30533,
#  'aid patent': 849,
#  'even brother like': 15426,
#  'brother like speak': 5968,
#  'like speak treat': 30813,
#  'speak treat like': 53928,
#  'treat like aid': 60136,
#  'like aid patent': 30534,
#  'per': 43909,
#  'request': 48464,
#  'mell': 34168,
#  'oru': 43013,
#  'minnaminungint': 34739,
#  'nurungu': 41451,
#  'vettam': 62328,
#  'set': 51275,
#  'callertun': 6954,
#  'caller': 6945,
#  'press': 46138,
#  'copi': 10264,
#  'friend': 18370,
#  'per request': 43939,
#  'request mell': 48475,
#  'mell mell': 34169,
#  'mell oru': 34171,
#  'oru minnaminungint': 43014,
#  'minnaminungint nurungu': 34740,
#  'nurungu vettam': 41452,
#  'vettam set': 62329,
#  'set callertun': 51277,
#  'callertun caller': 6955,
#  'caller press': 6948,
#  'press numbr': 46145,
#  'numbr copi': 39003,
#  'copi friend': 10269,
#  'friend callertun': 18381,
#  'per request mell': 43942,
#  'request mell mell': 48476,
#  'mell mell oru': 34170,
#  'mell oru minnaminungint': 34172,
#  'oru minnaminungint nurungu': 43015,
#  'minnaminungint nurungu vettam': 34741,
#  'nurungu vettam set': 41453,
#  'vettam set callertun': 62330,
#  'set callertun caller': 51278,
#  'callertun caller press': 6956,
#  'caller press numbr': 6949,
#  'press numbr copi': 46146,
#  'numbr copi friend': 39004,
#  'copi friend callertun': 10270,
#  'winner': 65050,
#  'valu': 62220,
#  'network': 37486,
#  'custom': 11011,
#  'select': 50681,
#  'receivea': 47838,
#  'prize': 46325,
#  'reward': 48655,
#  'claim': 8558,
#  'call': 6515,
#  'phonenumbr': 44324,
#  'code': 9104,
#  'klnumbr': 28590,
#  'valid': 62209,
#  'hour': 25453,
#  'winner valu': 65065,
#  'valu network': 62235,
#  'network custom': 37492,
#  'custom select': 11039,
#  'select receivea': 50704,
#  'receivea moneysymbnumbr': 47839,
#  'moneysymbnumbr prize': 35702,
#  'prize reward': 46362,
#  'reward claim': 48658,
#  'claim call': 8561,
#  'call phonenumbr': 6777,
#  'phonenumbr claim': 44371,
#  'claim code': 8571,
#  'code klnumbr': 9107,
#  'klnumbr valid': 28591,
#  'valid numbr': 62212,
#  'numbr hour': 39366,
#  'winner valu network': 65066,
#  'valu network custom': 62236,
#  'network custom select': 37494,
#  'custom select receivea': 11040,
#  'select receivea moneysymbnumbr': 50705,
#  'receivea moneysymbnumbr prize': 47840,
#  'moneysymbnumbr prize reward': 35709,
#  'prize reward claim': 46363,
#  'reward claim call': 48659,
#  'claim call phonenumbr': 8564,
#  'call phonenumbr claim': 6789,
#  'phonenumbr claim code': 44372,
#  'claim code klnumbr': 8572,
#  'code klnumbr valid': 9108,
#  'klnumbr valid numbr': 28592,
#  'valid numbr hour': 62214,
#  'mobil': 35188,
#  'month': 35820,
#  'entitl': 15177,
#  'updat': 61296,
#  'latest': 29595,
#  'colour': 9265,
#  'camera': 7043,
#  'co': 8931,
#  'mobil numbr': 35267,
#  'numbr month': 39696,
#  'month entitl': 35842,
#  'entitl updat': 15180,
#  'updat latest': 61308,
#  'latest colour': 29599,
#  'colour mobil': 9277,
#  'mobil camera': 35195,
#  'camera free': 7048,
#  'free call': 17979,
#  'call mobil': 6719,
#  'mobil updat': 35312,
#  'updat co': 61297,
#  'co free': 8966,
#  'free phonenumbr': 18119,
#  'mobil numbr month': 35272,
#  'numbr month entitl': 39699,
#  'month entitl updat': 35843,
#  'entitl updat latest': 15181,
#  'updat latest colour': 61310,
#  'latest colour mobil': 29601,
#  'colour mobil camera': 9278,
#  'mobil camera free': 35196,
#  'camera free call': 7049,
#  'free call mobil': 17983,
#  'call mobil updat': 6722,
#  'mobil updat co': 35313,
#  'updat co free': 61298,
#  'co free phonenumbr': 8967,
#  'gonna': 21064,
#  'home': 24831,
#  'soon': 53467,
#  'want': 63119,
#  'talk': 56374,
#  'stuff': 55265,
#  'anymor': 1997,
#  'tonight': 59657,
#  'cri': 10762,
#  'enough': 15096,
#  'today': 59139,
#  'gonna home': 21109,
#  'home soon': 24979,
#  'soon want': 53520,
#  'want talk': 63387,
#  'talk stuff': 56441,
#  'stuff anymor': 55266,
#  'anymor tonight': 2003,
#  'tonight cri': 59667,
#  'cri enough': 10767,
#  'enough today': 15128,
#  'gonna home soon': 21110,
#  'home soon want': 24980,
#  'soon want talk': 53521,
#  'want talk stuff': 63390,
#  'talk stuff anymor': 56442,
#  'stuff anymor tonight': 55267,
#  'anymor tonight cri': 2004,
#  'tonight cri enough': 59668,
#  'cri enough today': 10768,
#  'six': 52425,
#  'chanc': 7829,
#  'cash': 7525,
#  'pound': 45894,
#  'cshnumbr': 10866,
#  'cost': 10314,
#  'numbrp': 41026,
#  'day': 11652,
#  'numbrday': 40682,
#  'tsandc': 60459,
#  'repli': 48291,
#  'hl': 24629,
#  'info': 27029,
#  'six chanc': 52426,
#  'chanc win': 7857,
#  'win cash': 64952,
#  'cash numbr': 7565,
#  'numbr numbr': 39789,
#  'numbr pound': 40032,
#  'pound txt': 45922,
#  'txt cshnumbr': 60718,
#  'cshnumbr send': 10867,
#  'send numbr': 50949,
#  'numbr cost': 39005,
#  'cost numbrp': 10338,
#  'numbrp day': 41031,
#  'day numbrday': 11837,
#  'numbrday numbr': 40695,
#  'numbr tsandc': 40418,
#  'tsandc appli': 60460,
#  'appli repli': 2299,
#  'repli hl': 48345,
#  'hl numbr': 24630,
#  'numbr info': 39418,
#  'six chanc win': 52427,
#  'chanc win cash': 7858,
#  'win cash numbr': 64953,
#  'cash numbr numbr': 7567,
#  'numbr numbr numbr': 39830,
#  'numbr numbr pound': 39843,
#  'numbr pound txt': 40042,
#  'pound txt cshnumbr': 45923,
#  'txt cshnumbr send': 60719,
#  'cshnumbr send numbr': 10868,
#  'send numbr cost': 50951,
#  'numbr cost numbrp': 39006,
#  'cost numbrp day': 10339,
#  'numbrp day numbrday': 41032,
#  'day numbrday numbr': 11838,
#  'numbrday numbr tsandc': 40696,
#  'numbr tsandc appli': 40419,
#  'tsandc appli repli': 60461,
#  'appli repli hl': 2300,
#  'repli hl numbr': 48346,
#  'hl numbr info': 24631,
#  'urgent': 61786,
#  'membership': 34194,
#  'jackpot': 27503,
#  'httpaddr': 25622,
#  'lccltd': 29711,
#  'pobox': 45540,
#  'numbrldnwnumbranumbrrwnumbr': 40860,
#  'urgent numbr': 61805,
#  'week free': 64060,
#  'free membership': 18057,
#  'membership moneysymbnumbr': 34195,
#  'moneysymbnumbr numbr': 35674,
#  'numbr prize': 40058,
#  'prize jackpot': 46350,
#  'jackpot txt': 27504,
#  'txt word': 60827,
#  'word claim': 65636,
#  'claim numbr': 8607,
#  'numbr httpaddr': 39385,
#  'httpaddr lccltd': 25854,
#  'lccltd pobox': 29712,
#  'pobox numbrldnwnumbranumbrrwnumbr': 45548,
#  'urgent numbr week': 61808,
#  'numbr week free': 40535,
#  'week free membership': 64062,
#  'free membership moneysymbnumbr': 18058,
#  'membership moneysymbnumbr numbr': 34196,
#  'moneysymbnumbr numbr prize': 35684,
#  'numbr prize jackpot': 40061,
#  'prize jackpot txt': 46351,
#  'jackpot txt word': 27505,
#  'txt word claim': 60828,
#  'word claim numbr': 65637,
#  'claim numbr httpaddr': 8609,
#  'numbr httpaddr lccltd': 39391,
#  'httpaddr lccltd pobox': 25855,
#  'lccltd pobox numbrldnwnumbranumbrrwnumbr': 29713,
#  'search': 50277,
#  'right': 48706,
#  'thank': 57433,
#  'breather': 5795,
#  'promi': 46598,
#  'wont': 65533,
#  'take': 56142,
#  'help': 24024,
#  'grant': 21976,
#  'fulfil': 18738,
#  'wonder': 65472,
#  'bless': 5073,
#  'time': 58696,
#  'search right': 50298,
#  'right word': 48801,
#  'word thank': 65674,
#  'thank breather': 57444,
#  'breather promi': 5796,
#  'promi wont': 46620,
#  'wont take': 65578,
#  'take help': 56222,
#  'help grant': 24045,
#  'grant fulfil': 21977,
#  'fulfil promi': 18739,
#  'promi wonder': 46618,
#  'wonder bless': 65475,
#  'bless time': 5081,
#  'search right word': 50299,
#  'right word thank': 48802,
#  'word thank breather': 65675,
#  'thank breather promi': 57445,
#  'breather promi wont': 5797,
#  'promi wont take': 46621,
#  'wont take help': 65579,
#  'take help grant': 56223,
#  'help grant fulfil': 24046,
#  'grant fulfil promi': 21978,
#  'fulfil promi wonder': 18740,
#  'promi wonder bless': 46619,
#  'wonder bless time': 65476,
#  'date': 11590,
#  'sunday': 55573,
#  'date sunday': 11630,
#  'xxxmobilemovieclub': 66434,
#  'use': 61958,
#  'credit': 10718,
#  'click': 8772,
#  'wap': 63430,
#  'link': 30951,
#  'next': 37825,
#  'messag': 34262,
#  'xxxmobilemovieclub use': 66435,
#  'use credit': 61975,
#  'credit click': 10726,
#  'click wap': 8785,
#  'wap link': 63439,
#  'link next': 30956,
#  'next txt': 37879,
#  'txt messag': 60747,
#  'messag click': 34274,
#  'click httpaddr': 8779,
#  'httpaddr httpaddr': 25814,
#  'xxxmobilemovieclub use credit': 66436,
#  'use credit click': 61976,
#  'credit click wap': 10727,
#  'click wap link': 8786,
#  'wap link next': 63440,
#  'link next txt': 30957,
#  'next txt messag': 37880,
#  'txt messag click': 60748,
#  'messag click httpaddr': 34275,
#  'click httpaddr httpaddr': 8780,
#  'oh': 41715,
#  'watch': 63622,
#  'oh watch': 41856,
#  'eh': 14651,
#  'rememb': 48110,
#  'spell': 54008,
#  'name': 36904,
#  'ye': 66613,
#  'naughti': 37049,
#  'make': 32999,
#  'wet': 64620,
#  'eh rememb': 14658,
#  'rememb numbr': 48147,
#  'numbr spell': 40263,
#  'spell name': 54011,
#  'name ye': 36971,
#  'ye naughti': 66677,
#  'naughti make': 37058,
#  'make wet': 33198,
#  'eh rememb numbr': 14659,
#  'rememb numbr spell': 48148,
#  'numbr spell name': 40264,
#  'spell name ye': 54012,
#  'name ye naughti': 36972,
#  'ye naughti make': 66678,
#  'naughti make wet': 37059,
#  'fine': 17062,
#  'way': 63756,
#  'feel': 16557,
#  'gota': 21880,
#  'fine way': 17131,
#  'way feel': 63790,
#  'feel way': 16676,
#  'way gota': 63806,
#  'fine way feel': 17132,
#  'way feel way': 63791,
#  'feel way gota': 16677,
#  'england': 15001,
#  'macedonia': 32797,
#  'dont': 13418,
#  'miss': 34826,
#  'goal': 20856,
#  'team': 56632,
#  'news': 37791,
#  'ur': 61373,
#  'nation': 37023,
#  'eg': 14617,
#  'tri': 60169,
#  'wale': 62894,
#  'scotland': 50192,
#  'numbrtxt': 41306,
#  'únumbr': 67486,
#  'poboxoxnumbrwnumbrwq': 45574,
#  'england macedonia': 15006,
#  'macedonia dont': 32798,
#  'dont miss': 13522,
#  'miss goal': 34889,
#  'goal team': 20863,
#  'team news': 56638,
#  'news txt': 37814,
#  'txt ur': 60817,
#  'ur nation': 61645,
#  'nation team': 37030,
#  'team numbr': 56640,
#  'numbr eg': 39124,
#  'eg england': 14618,
#  'england numbr': 15008,
#  'numbr tri': 40410,
#  'tri wale': 60292,
#  'wale scotland': 62899,
#  'scotland numbrtxt': 50195,
#  'numbrtxt únumbr': 41310,
#  'únumbr poboxoxnumbrwnumbrwq': 67487,
#  'poboxoxnumbrwnumbrwq numbr': 45575,
#  'england macedonia dont': 15007,
#  'macedonia dont miss': 32799,
#  'dont miss goal': 13526,
#  'miss goal team': 34890,
#  'goal team news': 20864,
#  'team news txt': 56639,
#  'news txt ur': 37815,
#  'txt ur nation': 60820,
#  'ur nation team': 61646,
#  'nation team numbr': 37031,
#  'team numbr eg': 56641,
#  'numbr eg england': 39125,
#  'eg england numbr': 14619,
#  'england numbr tri': 15009,
#  'numbr tri wale': 40413,
#  'tri wale scotland': 60293,
#  'wale scotland numbrtxt': 62900,
#  'scotland numbrtxt únumbr': 50196,
#  'numbrtxt únumbr poboxoxnumbrwnumbrwq': 41311,
#  'únumbr poboxoxnumbrwnumbrwq numbr': 67488,
#  'seriou': 51176,
#  'seriou spell': 51190,
#  'seriou spell name': 51191,
#  'ha': 22895,
#  'go tri': 20797,
#  'tri numbr': 60256,
#  'month ha': 35853,
#  'ha ha': 22900,
#  'ha joke': 22907,
#  'go tri numbr': 20800,
#  'tri numbr month': 60259,
#  'numbr month ha': 39701,
#  'month ha ha': 35854,
#  'ha ha joke': 22904,
#  'pay': 43701,
#  'first': 17254,
#  'da': 11121,
#  'stock': 54865,
#  'comin': 9669,
#  'pay first': 43716,
#  'first lar': 17276,
#  'lar da': 29275,
#  'da stock': 11268,
#  'stock comin': 54866,
#  'pay first lar': 43717,
#  'first lar da': 17277,
#  'lar da stock': 29276,
#  'da stock comin': 11269,
#  'aft': 621,
#  'finish': 17148,
#  'lunch': 32636,
#  'str': 55094,
#  'lor': 31680,
#  'ard': 2393,
#  'smth': 52982,
#  'aft finish': 629,
#  'finish lunch': 17192,
#  'lunch go': 32653,
#  'go str': 20741,
#  'str lor': 55097,
#  'lor ard': 31695,
#  'ard numbr': 2398,
#  'numbr smth': 40235,
#  'smth lor': 52995,
#  'lor finish': 31741,
#  'finish ur': 17218,
#  'ur lunch': 61593,
#  'lunch alreadi': 32640,
#  'aft finish lunch': 630,
#  'finish lunch go': 17194,
#  'lunch go str': 32654,
#  'go str lor': 20742,
#  'str lor ard': 55098,
#  'lor ard numbr': 31696,
#  'ard numbr smth': 2406,
#  'numbr smth lor': 40236,
#  'smth lor finish': 52996,
#  'lor finish ur': 31742,
#  'finish ur lunch': 17221,
#  'ur lunch alreadi': 61594,
#  'ffffffffff': 16763,
#  'alright': 1282,
#  'meet': 33990,
#  'sooner': 53524,
#  'ffffffffff alright': 16764,
#  'alright way': 1324,
#  'way meet': 63827,
#  'meet sooner': 34105,
#  'ffffffffff alright way': 16765,
#  'alright way meet': 1325,
#  'way meet sooner': 63828,
#  'forc': 17680,
#  'eat': 14441,
#  'slice': 52643,
#  'realli': 47578,
#  'hungri': 26202,
#  'tho': 58288,
#  'suck': 55438,
#  'mark': 33459,
#  'get': 19255,
#  'worri': 65917,
#  'know': 28636,
#  'sick': 52029,
#  'turn': 60534,
#  'pizza': 44875,
#  'lol': 31338,
#  'forc eat': 17681,
#  'eat slice': 14497,
#  'slice realli': 52648,
#  'realli hungri': 47626,
#  'hungri tho': 26214,
#  'tho suck': 58305,
#  'suck mark': 55447,
#  'mark get': 33464,
#  'get worri': 19832,
#  'worri know': 65943,
#  'know sick': 28913,
#  'sick turn': 52041,
#  'turn pizza': 60550,
#  'pizza lol': 44878,
#  'forc eat slice': 17682,
#  'eat slice realli': 14498,
#  'slice realli hungri': 52649,
#  'realli hungri tho': 47627,
#  'hungri tho suck': 26215,
#  'tho suck mark': 58307,
#  'suck mark get': 55448,
#  'mark get worri': 33465,
#  'get worri know': 19834,
#  'worri know sick': 65944,
#  'know sick turn': 28914,
#  'sick turn pizza': 52042,
#  'turn pizza lol': 60551,
#  'alway': 1468,
#  'convinc': 10159,
#  'lol alway': 31341,
#  'alway convinc': 1481,
#  'lol alway convinc': 31342,
#  'catch': 7612,
#  'bu': 6083,
#  'fri': 18314,
#  'egg': 14637,
#  'tea': 56586,
#  'mom': 35390,
#  'left': 29926,
#  'dinner': 12939,
#  'love': 32056,
#  'catch bu': 7617,
#  'bu fri': 6090,
#  'fri egg': 18321,
#  'egg make': 14642,
#  'make tea': 33163,
#  'tea eat': 56588,
#  'eat mom': 14483,
#  'mom left': 35405,
#  'left dinner': 29937,
#  'dinner feel': 12948,
#  'feel love': 16629,
#  'catch bu fri': 7618,
#  'bu fri egg': 6091,
#  'fri egg make': 18322,
#  'egg make tea': 14643,
#  'make tea eat': 33164,
#  'tea eat mom': 56589,
#  'eat mom left': 14484,
#  'mom left dinner': 35406,
#  'left dinner feel': 29938,
#  'dinner feel love': 12949,
#  'amp': 1637,
#  'pack': 43262,
#  'car': 7246,
#  'let': 30146,
#  'room': 49046,
#  'back amp': 3588,
#  'amp pack': 1702,
#  'pack car': 43265,
#  'car let': 7277,
#  'let know': 30174,
#  'know room': 28894,
#  'back amp pack': 3589,
#  'amp pack car': 1703,
#  'pack car let': 43266,
#  'car let know': 7278,
#  'let know room': 30201,
#  'ahhh': 829,
#  'work': 65685,
#  'vagu': 62180,
#  'ahhh work': 830,
#  'work vagu': 65822,
#  'vagu rememb': 62181,
#  'rememb feel': 48123,
#  'feel like': 16618,
#  'like lol': 30682,
#  'ahhh work vagu': 831,
#  'work vagu rememb': 65823,
#  'vagu rememb feel': 62182,
#  'rememb feel like': 48124,
#  'feel like lol': 16626,
#  'wait': 62696,
#  'clear': 8746,
#  'sure': 55726,
#  'sarcast': 49653,
#  'us': 61866,
#  'wait still': 62810,
#  'still clear': 54676,
#  'clear sure': 8756,
#  'sure sarcast': 55809,
#  'sarcast want': 49655,
#  'want live': 63263,
#  'live us': 31166,
#  'wait still clear': 62811,
#  'still clear sure': 54677,
#  'clear sure sarcast': 8757,
#  'sure sarcast want': 55810,
#  'sarcast want live': 49656,
#  'want live us': 63265,
#  'yeah': 66750,
#  'apologet': 2239,
#  'fallen': 16264,
#  'actin': 325,
#  'spoilt': 54127,
#  'child': 8350,
#  'caught': 7675,
#  'till': 58660,
#  'badli': 3842,
#  'cheer': 8222,
#  'yeah got': 66789,
#  'got numbr': 21722,
#  'numbr apologet': 38795,
#  'apologet fallen': 2240,
#  'fallen actin': 16265,
#  'actin like': 326,
#  'like spoilt': 30815,
#  'spoilt child': 54128,
#  'child got': 8355,
#  'got caught': 21564,
#  'caught till': 7678,
#  'till numbr': 58685,
#  'numbr go': 39270,
#  'go badli': 20318,
#  'badli cheer': 3843,
#  'yeah got numbr': 66792,
#  'got numbr apologet': 21723,
#  'numbr apologet fallen': 38796,
#  'apologet fallen actin': 2241,
#  'fallen actin like': 16266,
#  'actin like spoilt': 327,
#  'like spoilt child': 30816,
#  'spoilt child got': 54129,
#  'child got caught': 8356,
#  'got caught till': 21565,
#  'caught till numbr': 7679,
#  'till numbr go': 58687,
#  'numbr go badli': 39274,
#  'go badli cheer': 20319,
#  'tell': 56718,
#  'anyth': 2032,
#  'tell anyth': 56730,
#  'fear': 16517,
#  'faint': 16222,
#  'housework': 25515,
#  'quick': 46990,
#  'cuppa': 10969,
#  'fear faint': 16518,
#  'faint housework': 16223,
#  'housework quick': 25516,
#  'quick cuppa': 46993,
#  'fear faint housework': 16519,
#  'faint housework quick': 16224,
#  'housework quick cuppa': 25517,
#  'subscript': 55412,
#  'rington': 48848,
#  'uk': 60958,
#  'charg': 7934,
#  'plea': 45276,
#  'confirm': 9914,
#  'thank subscript': 57541,
#  'subscript rington': 55418,
#  'rington uk': 48892,
#  'uk mobil': 60973,
#  'mobil charg': 35199,
#  'charg moneysymbnumbr': 7955,
#  'moneysymbnumbr month': 35664,
#  'month plea': 35872,
#  'plea confirm': 45302,
#  'confirm repli': 9923,
#  'repli ye': 48443,
#  'ye repli': 66715,
#  'repli charg': 48306,
#  'thank subscript rington': 57542,
#  'subscript rington uk': 55419,
#  'rington uk mobil': 48893,
#  'uk mobil charg': 60974,
#  'mobil charg moneysymbnumbr': 35200,
#  'charg moneysymbnumbr month': 7957,
#  'moneysymbnumbr month plea': 35665,
#  'month plea confirm': 35873,
#  'plea confirm repli': 45303,
#  'confirm repli ye': 9924,
#  'repli ye repli': 48446,
#  'ye repli charg': 66716,
#  'yup': 67369,
#  'look': 31557,
#  'msg': 36208,
#  'xuhui': 66399,
#  'learn': 29755,
#  'numbrnd': 40971,
#  'lesson': 30108,
#  'numbram': 40630,
#  'yup ok': 67412,
#  'ok go': 41978,
#  'go home': 20471,
#  'home look': 24931,
#  'look time': 31647,
#  'time msg': 58852,
#  'msg xuhui': 36351,
#  'xuhui go': 66400,
#  'go learn': 20527,
#  'learn numbrnd': 29762,
#  'numbrnd may': 40977,
#  'may lesson': 33695,
#  'lesson numbram': 30136,
#  'yup ok go': 67413,
#  'ok go home': 41980,
#  'go home look': 20477,
#  'home look time': 24932,
#  'look time msg': 31648,
#  'time msg xuhui': 58853,
#  'msg xuhui go': 36352,
#  'xuhui go learn': 66401,
#  'go learn numbrnd': 20528,
#  'learn numbrnd may': 29763,
#  'numbrnd may lesson': 40978,
#  'may lesson numbram': 33696,
#  'oop': 42738,
#  'roommat': 49098,
#  'done': 13350,
#  'oop let': 42739,
#  'know roommat': 28895,
#  'roommat done': 49101,
#  'oop let know': 42740,
#  'let know roommat': 30202,
#  'know roommat done': 28896,
#  'see': 50399,
#  'letter': 30259,
#  'see letter': 50480,
#  'letter car': 30260,
#  'see letter car': 50481,
#  'decid': 12192,
#  'anyth lor': 2085,
#  'lor decid': 31719,
#  'anyth lor decid': 2087,
#  'hello': 23935,
#  'saturday': 49736,
#  'tomo': 59468,
#  'invit': 27284,
#  'hello saturday': 24002,
#  'saturday go': 49741,
#  'go text': 20770,
#  'text see': 57310,
#  'see decid': 50431,
#  'decid anyth': 12193,
#  'anyth tomo': 2111,
#  'tomo tri': 59486,
#  'tri invit': 60238,
#  'invit anyth': 27287,
#  'hello saturday go': 24003,
#  'saturday go text': 49742,
#  'go text see': 20771,
#  'text see decid': 57312,
#  'see decid anyth': 50432,
#  'decid anyth tomo': 12194,
#  'anyth tomo tri': 2112,
#  'tomo tri invit': 59487,
#  'tri invit anyth': 60239,
#  'pl': 44886,
#  'ahead': 820,
#  'watt': 63748,
#  'weekend': 64171,
#  'abiola': 49,
#  'pl go': 44940,
#  'go ahead': 20283,
#  'ahead watt': 827,
#  'watt want': 63749,
#  'want sure': 63380,
#  'sure great': 55764,
#  'great weekend': 22143,
#  'weekend abiola': 64172,
#  'pl go ahead': 44941,
#  'go ahead watt': 20285,
#  ...}

# %%
X_ngrams.shape
# Out:
# (5572, 67491)

# %% [markdown]
# Training Model

# %%
from sklearn.svm import SVC
from sklearn import svm
from sklearn.metrics import accuracy_score 
import sklearn.metrics as metrics 
X_train, X_test, y_train, y_test = train_test_split(X_ngrams,y_enc,test_size=0.2,random_state=42,stratify=y_enc)
clf = svm.SVC(kernel='linear', C=1, gamma=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
metrics.f1_score(y_test, y_pred)
# Out:
# 0.9018181818181819

# %%
pd.DataFrame(
    metrics.confusion_matrix(y_test, y_pred),
    index=[['actual', 'actual'], ['spam', 'ham']],
    columns=[['predicted', 'predicted'], ['spam', 'ham']]
)
# Out:
#             predicted
#                  spam  ham
# actual spam       964    2
#        ham         25  124
